# %%
from sklearn.linear_model import LinearRegression 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
diab = datasets.load_diabetes()
#print(diab["DESCR"])
print(diab.data.shape ,diab.target.shape)
diab.feature_names
# Out:
# (442, 10) (442,)
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
db = pd.DataFrame(diab.data)
db.columns=diab.feature_names
db.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(diab.data,diab.target,test_size= 0.2,random_state = 1)#this function returns 4 parameters
x_train.shape , x_test.shape
# Out:
# ((353, 10), (89, 10))

# %%
clf2=LinearRegression()
clf2.fit(x_train,y_train)
clf2.score(x_test , y_test) , clf2.score(x_train,y_train)
# Out:
# (0.43843604017332694, 0.533228642689112)

# %%
clf2.coef_ ,clf2.intercept_
# Out:
# (array([ -30.62168241, -272.25451707,  528.84444333,  327.70269026,
#         -581.01413007,  332.96286278,  -27.97606192,  139.28448979,
#          665.07521004,   61.90596378]), 151.43006895898006)

# %%
print(diab)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
xn = pd.DataFrame(x_train)
xn
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 1    0.012648  0.050680  0.000261 -0.011409  0.039710  0.057245 -0.039719
# 2    0.070769 -0.044642  0.012117  0.042530  0.071357  0.053487  0.052322
# 3   -0.056370 -0.044642 -0.011595 -0.033214 -0.046975 -0.047660  0.004460
# 4   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 5   -0.027310 -0.044642 -0.066563 -0.112400 -0.049727 -0.041397  0.000779
# 6    0.045341 -0.044642  0.071397  0.001215 -0.009825 -0.001001  0.015505
# 7   -0.063635 -0.044642 -0.033151 -0.033214  0.001183  0.024051 -0.024993
# 8    0.012648  0.050680 -0.022373 -0.029771  0.010815  0.028435 -0.021311
# 9   -0.023677 -0.044642  0.045529  0.090730 -0.018080 -0.035447  0.070730
# 10  -0.009147 -0.044642  0.037984 -0.040099 -0.024960 -0.003819 -0.043401
# 11   0.067136 -0.044642  0.036907 -0.050428 -0.023584 -0.034508  0.048640
# ...
